# %%
import pandas as pd
con=pd.read_csv(r"C:\Users\91808\Desktop\EDA\Self study\countries-of-the-world (1)\countries of the world.csv")

# %%
#https://towardsdatascience.com/analyze-the-data-through-data-visualization-using-seaborn-255e1cd3948e

# %%
#https://seaborn.pydata.org/tutorial.html#

# %%
con.isnull().sum()
con.dropna(inplace=True)
con.shape
# Out:
# (179, 20)

# %%
#dropped all missing values

# %%
con.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179 entries, 0 to 226
# Data columns (total 20 columns):
# Country                               179 non-null object
# Region                                179 non-null object
# Population                            179 non-null int64
# Area (sq. mi.)                        179 non-null int64
# Pop. Density (per sq. mi.)            179 non-null float64
# Coastline (coast/area ratio)          179 non-null float64
# Net migration                         179 non-null float64
# Infant mortality (per 1000 births)    179 non-null float64
# GDP ($ per capita)                    179 non-null float64
# Literacy (%)                          179 non-null float64
# Phones (per 1000)                     179 non-null float64
# Arable (%)                            179 non-null float64
# Crops (%)                             179 non-null float64
# Other (%)                             179 non-null float64
# ...

# %%
con.describe()
# Out:
#          Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# count  1.790000e+02    1.790000e+02                  179.000000
# mean   3.421415e+07    5.641830e+05                  294.805028
# std    1.317639e+08    1.395657e+06                 1379.352557
# min    1.347700e+04    2.800000e+01                    1.800000
# 25%    1.188580e+06    1.991500e+04                   26.800000
# 50%    6.940432e+06    1.184800e+05                   66.900000
# 75%    2.086014e+07    4.964410e+05                  164.700000
# max    1.313974e+09    9.631420e+06                16183.000000
#
#        Coastline (coast/area ratio)  Net migration  \
# count                    179.000000     179.000000
# mean                      16.495196      -0.206536
# std                       73.977601       4.751216
# min                        0.000000     -20.990000
# 25%                        0.090000      -1.315000
# 50%                        0.630000       0.000000
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import matplotlib.style as style 
style.available
fig = plt.figure(figsize=(5,5))


style.use('seaborn-poster') #sets the size of the charts
style.use('ggplot')

# %%
#studying univariate distributions

# %%
#histogram

# %%
# # # # # Histograms are likely familiar, and a hist function already exists in matplotlib. 
# # # # # A histogram represents the distribution of data by forming bins along the range of the data and 
# # # # # then drawing bars to show the number of observations that fall in each bin.

# # # # Histograms bin the numerical values into various ranges. 
# # # # Then a continous function is passed on top of these unique bins by using Kernel Density Estimate,
# # # # to get a continous probability distribution of the random variable.


# # # The vertical 'rugged' lines correspond to the actual data distribution ,
# # # # and the blue continuos curve is the kernel estimate for the data distribution.

# # #can be useful to understand the structure of data and identify the outliers


# # #Now, what if we pushed this further and decreased the intervals even more? 
# # You can imagine that the intervals would eventually get so small that we could represent the probability distribution of X, 
# # not as a density histogram, but rather as a curve (by connecting the "dots" at the tops of the tiny tiny tiny rectangles)
# ------Kernel Density Estimator

# The kernel density estimator is the estimated pdf of a random variable. It is defined as
# Kernel density equation

# Similar to histograms, KDE plots the density of observations on one axis with height along the other axis.

# %%
fig = plt.figure(figsize=(5,5))

sns.distplot(con['GDP ($ per capita)'], kde=True, rug=True);

# %%
fig = plt.figure(figsize=(10,10))

sns.distplot(con['Population'], bins=10,kde=True, rug=True);

# %%
fig = plt.figure(figsize=(10,10))

sns.distplot(con['Pop. Density (per sq. mi.)'], bins=10,kde=True, rug=True);

#as per below graph, we can see an entry beyond 15000 pop.density, on investigatn we found that it belongs to MACAU.
#as per facts it is most densely populated region hence not an outlier.

# %%
a=con['Pop. Density (per sq. mi.)']>15000
con[a]
# Out:
#     Country                         Region  Population  Area (sq. mi.)  \
# 122  Macau   ASIA (EX. NEAR EAST)               453125              28
#
#      Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 122                     16183.0                        146.43           4.86
#
#      Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 122                                4.39             19400.0          94.5
#
#      Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  Birthrate  \
# 122              384.9         0.0        0.0      100.0      2.0       8.48
#
#      Deathrate  Agriculture  Industry  Service
# 122       4.47        0.001     0.072    0.927

# %%
fig = plt.figure(figsize=(10,10))

sns.distplot(con['Area (sq. mi.)'], bins=10,kde=True, rug=True);
# Out:
# C:\Users\91808\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
b=con['Area (sq. mi.)']<=100
con[b]
# Out:
#       Country                               Region  Population  \
# 22   Bermuda   NORTHERN AMERICA                          65773
# 122    Macau         ASIA (EX. NEAR EAST)               453125
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 22               53                      1241.0                        194.34
# 122              28                     16183.0                        146.43
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 22            2.49                                8.53             36000.0
# 122           4.86                                4.39             19400.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 22           98.0              851.4        20.0        0.0       80.0
# 122          94.5              384.9         0.0        0.0      100.0
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# ...

# %%
fig = plt.figure(figsize=(10,10))

sns.distplot(con['Coastline (coast/area ratio)'], bins=10,kde=True, rug=True);

# %%
c=con['Coastline (coast/area ratio)']>800
con[c]

#its an island so nt surprised
# Out:
#                    Country                               Region  Population  \
# 136  Micronesia. Fed. St.   OCEANIA                                  108004
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 136             702                       153.9                        870.66
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 136         -20.99                               30.21              2000.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 136          89.0              114.8        5.71      45.71      48.58
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 136      2.0      24.68       4.75        0.289     0.152    0.559

# %%
d=con['Coastline (coast/area ratio)']==0
e=con[d]
e.shape

#35 countries dnt have any coast line
# Out:
# (35, 20)

# %%
fig = plt.figure(figsize=(10,10))

sns.distplot(con['Net migration'], bins=5,kde=True, rug=True);
# Out:
# C:\Users\91808\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
f=con['Net migration']>0
g=con[f]
print(g.shape)
h=con['Net migration']>20
con[h]
#for 48 countries, net migration is +ve: there are more people entering than leaving an area.
#its the highest for Afghanistan
# Out:
# (48, 20)
#         Country                         Region  Population  Area (sq. mi.)  \
# 0  Afghanistan   ASIA (EX. NEAR EAST)             31056997          647500
#
#    Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 0                        48.0                           0.0          23.06
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 0                              163.07               700.0          36.0
#
#    Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  Birthrate  \
# 0                3.2       12.13       0.22      87.65      1.0       46.6
#
#    Deathrate  Agriculture  Industry  Service
# 0      20.34         0.38      0.24     0.38

# %%
i=con['Net migration']<0
j=con[i]
print(j.shape)
k=con['Net migration']<-20
con[k]

#for 82 countries, net migration is -ve, i.e. people leaving are more than those entering
#its the most Micronesia
# Out:
# (82, 20)
#                    Country                               Region  Population  \
# 136  Micronesia. Fed. St.   OCEANIA                                  108004
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 136             702                       153.9                        870.66
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 136         -20.99                               30.21              2000.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 136          89.0              114.8        5.71      45.71      48.58
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 136      2.0      24.68       4.75        0.289     0.152    0.559

# %%
fig = plt.figure(figsize=(10,10))

sns.distplot(con['Infant mortality (per 1000 births)'], bins=10,kde=True, rug=True);

# %%
l=con['Infant mortality (per 1000 births)']>150
con[l]

#infant mortality is highest in Afghanistan
# Out:
#         Country                         Region  Population  Area (sq. mi.)  \
# 0  Afghanistan   ASIA (EX. NEAR EAST)             31056997          647500
#
#    Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 0                        48.0                           0.0          23.06
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 0                              163.07               700.0          36.0
#
#    Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  Birthrate  \
# 0                3.2       12.13       0.22      87.65      1.0       46.6
#
#    Deathrate  Agriculture  Industry  Service
# 0      20.34         0.38      0.24     0.38

# %%
m=con['Infant mortality (per 1000 births)']<3
con[m]
#fOUND THE LEAST IN Hong Kong, Singapore and Sweden
# Out:
#         Country                               Region  Population  \
# 91   Hong Kong         ASIA (EX. NEAR EAST)              6940432
# 184  Singapore         ASIA (EX. NEAR EAST)              4492150
# 195     Sweden   WESTERN EUROPE                          9016596
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 91             1092                      6355.7                         67.12
# 184             693                      6482.2                         27.85
# 195          449964                        20.0                          0.72
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 91            5.24                                2.97             28800.0
# 184          11.53                                2.29             23700.0
# 195           1.67                                2.77             26800.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# ...

# %%
fig = plt.figure(figsize=(10,10))

sns.distplot(con['GDP ($ per capita)'], bins=10,kde=True, rug=True);

# %%
n=con['GDP ($ per capita)']==37800
print(con[n])
o=con['GDP ($ per capita)']==500
con[o]
#p=con['GDP ($ per capita)'].min()
# Out:
#             Country                               Region  Population  \
# 154         Norway   WESTERN EUROPE                          4610820
# 214  United States   NORTHERN AMERICA                      298444215
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 154          323802                        14.2                          7.77
# 214         9631420                        31.0                          0.21
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 154           1.74                                 3.7             37800.0
# 214           3.41                                 6.5             37800.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 154         100.0              461.7        2.87       0.00      97.13
# 214          97.0              898.0       19.13       0.22      80.65
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# ...

# %%
# We can see that if we use the kdeplot() function in seaborn, we get the same curve. 
# This function is used by distplot(), but it provides a more direct interface with easier access 
# to other options when you just want the density estimate:

# %%
fig = plt.figure(figsize=(10,10))

sns.kdeplot(con['Net migration'], shade=True,bw=-0.2,label="bw:-0.2");
sns.kdeplot(con['Net migration'], shade=True,bw=2,label="bw:2");

#The bandwidth (bw) parameter of the KDE controls how tightly the estimation is fit to the data, 
# much like the bin size in a histogram. It corresponds to the width of the kernels we plotted above. 
# The default behavior tries to guess a good value using a common reference rule, 
# but it may be helpful to try larger or smaller values:

# %%
# Fitting parametric distributions
# You can also use distplot() to fit a parametric distribution to a dataset and 
# visually evaluate how closely it corresponds to the observed data:

# %%
from scipy.stats import gamma

# sns.distplot(con['Net migration'], kde=False, fit=stats.gamma);

# %%
# import numpy as np
# from scipy import stats
# fig = plt.figure(figsize=(10,10))

# x = np.random.gamma(6, size=200)
# sns.distplot(x, kde=False, fit=stats.gamma);

# %%
# #CategoricAL PLOTS

# https://datascienceplus.com/seaborn-categorical-plots-in-python/

# %%
fig = plt.figure(figsize=(10,10))

con['Region'].value_counts().plot(kind='bar')

# %%
sns.countplot(y="Region", data=con, color="c");

# %%
#pi charts work better in categorical data at times

con['Region'].value_counts().plot(kind='pie')

# %%
fig = plt.figure(figsize=(40,20))

sns.barplot(x='Region',y='Population',data=con)
#Northern America Region contributes max in population and Baltics and Oceania the minimum

# %%
fig = plt.figure(figsize=(40,20))

sns.barplot(x='Region',y='GDP ($ per capita)',data=con)

# %%
fig = plt.figure(figsize=(40,20))

sns.barplot(x='Region',y='Coastline (coast/area ratio)',data=con)

# %%
fig = plt.figure(figsize=(40,20))

sns.boxplot(x='Region',y='Population',data=con,palette='rainbow')
# useful for finding the outliers

# %%
fig = plt.figure(figsize=(50,30))

sns.boxplot(data=con,palette='coolwarm',orient='h')

# %%
fig = plt.figure(figsize=(50,30))

sns.stripplot(x="Region", y="Population", data=con)

# %%
#bi variate analysis

# %%
sns.jointplot(x="Area (sq. mi.)", y="Population", data=con);

# %%
sns.countplot(y="Climate", data=con, color="c");
#max countries lies in type 2 of climate

# %%
#https://towardsdatascience.com/analyze-the-data-through-data-visualization-using-seaborn-255e1cd3948e
sns.relplot(y="Net migration", x="Population", data=con);
#Default plot type of relplot is scatterplot. 
#It shows the relationship between two variables. 
#So, if you need to find the correlation between two variables scatterplot can be used.
#you can add a third variable as well thru hue

# %%
sns.relplot(y="Net migration", x="Population", data=con,hue='Climate');
#makes no sense

# %%
# Line plot
# This plot is similar to the scatterplot but instead of dots, 
# it displays the line joining all the dots by arranging the variable value represented on the x-axis.

# %%
sns.relplot(y="Population", x="Area (sq. mi.)", kind="line", data=con)

# %%
# As line plot arranges the rows as per total_bill and then joins the points we can disable the sorting.

# %%
sns.relplot(y="Population", x="Area (sq. mi.)", kind="line", data=con,sort=False,color='limegreen')

# %%
# #improving your graphs

# https://medium.com/@andykashyap/top-5-tricks-to-make-plots-look-better-9f6e687c1e08
